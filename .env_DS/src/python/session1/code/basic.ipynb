# %%
list_one = [1,2,3,4,"DEPI","learning",True,[1,2,3,"True",["ml","dl","ds"]]]
print(type(list_one))
list_one[7][4][0]
# Out:
# <class 'list'>
# 'ml'

# %%
name = "Beshoy"
list1 = list(name)
print(type(name))
print(type(list1))
print(name)
print(list1)
# Out:
# <class 'str'>
# <class 'list'>
# Beshoy
# ['B', 'e', 's', 'h', 'o', 'y']

# %%
list1.append(4)
list1.insert(0,9)
print(list1)
# Out:
# [9, 9, 9, 9, 'B', 'e', 's', 'h', 'o', 'y', 4, 4, 4, 4, 4]

# %%
list_1 = [1,2,3]
list_2 = [4,5,6]
list_3 = list_1 + list_2
print(list_3)
list_1.extend(list_2)
print(list_1)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6]

# %%
list_1 = ["Beshoy" , "Magdy" , "Abdelsaid" ]
list_1.remove("Beshoy")
print(list_1)
# Out:
# ['Magdy', 'Abdelsaid']

# %%
list_1 = ["Beshoy" , "Magdy" , "Abdelsaid" , "Beshoy" ]
list_1.remove("Beshoy")
print(list_1)
# Out:
# ['Magdy', 'Abdelsaid', 'Beshoy']

# %%
list_1 = ["Beshoy" , "Magdy" , "Abdelsaid" , "Beshoy" ]
new = list_1.pop()
print(list_1)
print(new)
# Out:
# ['Beshoy', 'Magdy', 'Abdelsaid']
# Beshoy

# %%
name = input("enter your name")
id = input("enter your id")
print(f"my name is {name} and my id is {id}")
# Out:
# my name is ds and my id is 22

# %%
removed = input("enter what do you want to remove")

list_1 = ["amit","learning","python"]
list_1.remove(removed)
print(f"output list after removing is : {list_1}")
# Out:
# output list after removing is : ['learning', 'python']

# %%
list_4 = [1,6,2,9,5,4,7,3]
list_4.index(2)
list_4.count(2)

list_4.reverse()
print(list_4)

list_4.sort()
print(list_4)

list_4.sort(reverse=True)
print(list_4)

list_4.clear()
print(list_4)
# Out:
# [3, 7, 4, 5, 9, 2, 6, 1]
# [1, 2, 3, 4, 5, 6, 7, 9]
# [9, 7, 6, 5, 4, 3, 2, 1]
# []

# %%
tuple_1 = (1,5,3,6,9,4,8,7)
print(tuple_1)
print(tuple_1[2])

# tuple_1 [0] = 2  #ERROR Tuple is unchangable
# Out:
# (1, 5, 3, 6, 9, 4, 8, 7)
# 3

# %%
name = "Beshoy"
name = tuple(name)
print(name)
# Out:
# ('B', 'e', 's', 'h', 'o', 'y')

# %%
set_1 = {1,2,3}
set_2 = {3,4,5}
print(set_1.intersection(set_2))
print(set_1.union(set_2))
print(set_1.difference(set_2))
# Out:
# {3}
# {1, 2, 3, 4, 5}
# {1, 2}

# %%
dict_1 = {"key1" : 12 , "key2" : "python"}
print(dict_1["key1"])
dict_1["key1"] = 22
print(dict_1)
# Out:
# 12
# {'key1': 22, 'key2': 'python'}

# %%
dict_3 = [("key1",1),("key2",2)]
conv_dict_3 = dict(dict_3)
print(conv_dict_3)
# Out:
# {'key1': 1, 'key2': 2}

# %%
num = int(input("enter your number"))
print(type(num))
# Out:
# <class 'int'>

# %%
5/3
5//3
5%3
5*3
5**3
# Out:
# 125

# %%
num1 = int(input("enter number 1"))
num2 = int(input("enter number 2"))

print(f"addition is : {num1+num2}")
print(f"subtraction is : {num1-num2}")
print(f"multiplication is : {num1*num2}")
print(f"division is : {num1/num2}")
# Out:
# addition is : 3
# subtraction is : -1
# multiplication is : 2
# division is : 0.5

# %%
x = 20
result = "even" if x % 2 == 0 else "odd"
print(result)
# Out:
# even

# %%
x = 20
y = 15
result = x - y if x > y  else x + y
print(result)
# Out:
# 5
