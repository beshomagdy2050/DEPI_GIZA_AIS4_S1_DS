# %% [markdown]
# ## QUESTION 1

# %%
#Create a function which answers the question "Are you playing banjo?".
#If your name starts with the letter "R" or lower case "r", you are playing banjo!
#The function takes a name as its only argument, and returns one of the following strings:
#name + " plays banjo" 
#name + " does not play banjo"



def playing_banjo (name) :
    if name[0] == "R" or name[0] == "r":
        return(f"{name} plays banjo\n")
    else :
        return(f"{name} does not play banjo")

Name = input ("are you playing banjo ?\n ")

print(playing_banjo(Name))
# Out:
# Rsds plays banjo

# %% [markdown]
# ## QUESTION 2

# %%
# Complete the solution so that it reverses all of the words within the string passed in.
#Words are separated by exactly one space and there are no leading or trailing spaces.
#Example(Input --> Output):
#"The greatest victory is that which requires no battle" --> "battle no requires which that is victory greatest The"


def reverse_sentence (sen) :
    sen = sen.split()
    sen1 = []
    length = len(sen)
    for i in range (length):
        sen1.append(sen[length-i-1])
    print(" ".join(sen1))

sentence = "The greatest victory is that which requires no battle"

print(reverse_sentence (sentence))
# Out:
# battle no requires which that is victory greatest The
# None

# %% [markdown]
# ## QUESTION 3

# %%
# THANOS PROJECT
# MAKE A FUCTION TO DO THAT :
# 1 - OPEN THE WHOLE FLDER
# 2 - CREATE NUMBER OF FILES INSIDE IT
# 3 - CHECK THE LEN OF THE FILES IN THAT FOLDER
# 4 - DELETE RANDOM HALF OF THIS FOLDERS
# 5 - CHECK THE RESULT

import random
import os


def create_dir (path):
    if not os.path.exists(path) :
        os.makedirs(path)
        print("directory created succesfully (empty)\n")
        return
    print("directory already exist\n")
    
def create_files (path,files_num):
    
    for i in range (files_num) :
        file_name = f"file_{i}.txt"
        file_path = os.path.join(path,file_name)
        with open (file_path,"w+") as file :
            file.write(f"this if file_{i}\n")
    print(f"{files_num} files created succesfully\n")   
        
        
        
def check_files (path) :
    
    base = os.listdir(path)    
    return base

        
def delete_files (path , deleted_files_num) :
    
    base = os.listdir(path)  
    while deleted_files_num > 0 :
        deleted = random.choice(base)
        if os.path.exists(path + "/" + str(deleted))  :
            deleted = os.remove(path + "/" + deleted)
            deleted_files_num = deleted_files_num - 1
        

    
path_1 = "D:/DEPI/DEPI_GIZA_AIS4_S1_DS/DEPI_GIZA_AIS4_S1_DS/.env_DS/src/python/session3/assignment/files"
create_dir(path_1)

create_files (path_1 , 6)
print(f"\nnumber of files in this folder after creation : {len(check_files (path_1))}\n")    
print(check_files (path_1))

delete_files (path_1 , 3)
print(f"\nnumber of files in this folder after deletion : {len(check_files (path_1))}\n")    
print(check_files (path_1))
# Out:
# directory already exist
#
# 6 files created succesfully
#
#
# number of files in this folder after creation : 6
#
# ['file_0.txt', 'file_1.txt', 'file_2.txt', 'file_3.txt', 'file_4.txt', 'file_5.txt']
#
# number of files in this folder after deletion : 3
#
# ['file_1.txt', 'file_3.txt', 'file_4.txt']
